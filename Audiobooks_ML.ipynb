# %%
import numpy as np
import tensorflow as tf

# %%
npz = np.load('Audiobooks_data_train.npz')

train_inputs = npz['inputs'].astype(np.float64)
train_targets = npz['targets'].astype(np.int32)

npz = np.load('Audiobooks_data_validation.npz')

validation_inputs = npz['inputs'].astype(np.float64)
validation_targets = npz['targets'].astype(np.int32)

npz = np.load('Audiobooks_data_test.npz')

test_inputs = npz['inputs'].astype(np.float64)
test_targets = npz['targets'].astype(np.int32)

# %% [markdown]
# ### Model
# OUTLINE, OPTIMIZERS, LOSS, EARLY STOPPING AND TRAINING

# %%
input_size = 10
output_size = 2
hidden_layer_size = 50

model = tf.keras.Sequential([
                            tf.keras.layers.Dense(hidden_layer_size, activation = 'relu'),
                            tf.keras.layers.Dense(hidden_layer_size, activation = 'relu'),
                            tf.keras.layers.Dense(output_size, activation = 'softmax'),
                            ])

model.compile(optimizer='adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])

batch_size = 100

max_epochs  = 100

early_stopping = tf.keras.callbacks.EarlyStopping(patience = 2)

model.fit( train_inputs,
         train_targets,
         batch_size = batch_size,
         epochs = max_epochs,
         callbacks = [early_stopping],
         validation_data = (validation_inputs, validation_targets),
         verbose = 2)
# Out:
# Train on 3579 samples, validate on 447 samples
# Epoch 1/100
# 3579/3579 - 0s - loss: 0.5582 - accuracy: 0.7150 - val_loss: 0.4965 - val_accuracy: 0.7383
# Epoch 2/100
# 3579/3579 - 0s - loss: 0.4512 - accuracy: 0.7751 - val_loss: 0.4372 - val_accuracy: 0.7606
# Epoch 3/100
# 3579/3579 - 0s - loss: 0.4074 - accuracy: 0.7860 - val_loss: 0.4116 - val_accuracy: 0.7763
# Epoch 4/100
# 3579/3579 - 0s - loss: 0.3835 - accuracy: 0.7932 - val_loss: 0.3885 - val_accuracy: 0.8054
# Epoch 5/100
# 3579/3579 - 0s - loss: 0.3669 - accuracy: 0.8050 - val_loss: 0.3863 - val_accuracy: 0.7942
# Epoch 6/100
# 3579/3579 - 0s - loss: 0.3578 - accuracy: 0.8128 - val_loss: 0.3796 - val_accuracy: 0.8098
# Epoch 7/100
# 3579/3579 - 0s - loss: 0.3516 - accuracy: 0.8047 - val_loss: 0.3607 - val_accuracy: 0.8210
# Epoch 8/100
# 3579/3579 - 0s - loss: 0.3462 - accuracy: 0.8050 - val_loss: 0.3644 - val_accuracy: 0.8143
# Epoch 9/100
# 3579/3579 - 0s - loss: 0.3417 - accuracy: 0.8161 - val_loss: 0.3544 - val_accuracy: 0.8166
# Epoch 10/100
# 3579/3579 - 0s - loss: 0.3400 - accuracy: 0.8097 - val_loss: 0.3681 - val_accuracy: 0.8210
# Epoch 11/100
# 3579/3579 - 0s - loss: 0.3356 - accuracy: 0.8178 - val_loss: 0.3548 - val_accuracy: 0.8210

# %% [markdown]
# ## Test the model

# %%
test_loss, test_accuracy = model.evaluate(test_inputs, test_targets)
# Out:
# 448/1 [========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print('Test loss : {0: .2f} Test accuracy: {1: .2f}% '.format(test_loss, test_accuracy*100.))
# Out:
# Test loss :  0.35 Test accuracy:  79.24%
